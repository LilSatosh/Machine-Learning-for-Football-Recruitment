# %%
import pandas as pd

# %%
mv_dataset = pd.read_csv("market_value_dataset.csv")
print(mv_dataset)
# Out:
#            comp_name  region  country  season_start_year            squad  \
# 0     Premier League  Europe  England               2024  Manchester City
# 1     Premier League  Europe  England               2024  Manchester City
# 2     Premier League  Europe  England               2024  Manchester City
# 3     Premier League  Europe  England               2024  Manchester City
# 4     Premier League  Europe  England               2024  Manchester City
# ...              ...     ...      ...                ...              ...
# 5370         Ligue 1  Europe   France               2024       Angers SCO
# 5371         Ligue 1  Europe   France               2024       Angers SCO
# 5372         Ligue 1  Europe   France               2024       Angers SCO
# 5373         Ligue 1  Europe   France               2024       Angers SCO
# 5374         Ligue 1  Europe   France               2024       Angers SCO
#
#      player_num        player_name player_position  player_dob  player_age  \
# ...

# %%
#convert dob column to datetime format and extract year
mv_dataset['birth_year'] = pd.to_datetime(mv_dataset['player_dob']).dt.year

# %%
print(mv_dataset)
# Out:
#            comp_name  region  country  season_start_year            squad  \
# 0     Premier League  Europe  England               2024  Manchester City
# 1     Premier League  Europe  England               2024  Manchester City
# 2     Premier League  Europe  England               2024  Manchester City
# 3     Premier League  Europe  England               2024  Manchester City
# 4     Premier League  Europe  England               2024  Manchester City
# ...              ...     ...      ...                ...              ...
# 5370         Ligue 1  Europe   France               2024       Angers SCO
# 5371         Ligue 1  Europe   France               2024       Angers SCO
# 5372         Ligue 1  Europe   France               2024       Angers SCO
# 5373         Ligue 1  Europe   France               2024       Angers SCO
# 5374         Ligue 1  Europe   France               2024       Angers SCO
#
#      player_num        player_name player_position  player_dob  player_age  \
# ...

# %%
mv_dataset.to_csv('mv_data_with_year.csv', index=False)
